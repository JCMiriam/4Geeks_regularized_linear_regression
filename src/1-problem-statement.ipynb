# %%
import pandas as pd

main_df = pd.read_csv('../data/raw/demographic_health_data.csv')
main_df.head()
# Out:
#    fips  TOT_POP    0-9  0-9 y/o % of total pop  19-Oct  \
# 0  1001    55601   6787               12.206615    7637
# 1  1003   218022  24757               11.355276   26913
# 2  1005    24881   2732               10.980266    2960
# 3  1007    22400   2456               10.964286    2596
# 4  1009    57840   7095               12.266598    7570
#
#    10-19 y/o % of total pop  20-29  20-29 y/o % of total pop  30-39  \
# 0                 13.735364   6878                 12.370281   7089
# 1                 12.344167  23579                 10.814964  25213
# 2                 11.896628   3268                 13.134520   3201
# 3                 11.589286   3029                 13.522321   3113
# 4                 13.087828   6742                 11.656293   6884
#
#    30-39 y/o % of total pop  ...  COPD_number  diabetes_prevalence  \
# 0                 12.749771  ...         3644                 12.9
# 1                 11.564429  ...        14692                 12.0
# ...

# %%
# Get Data Frame structure data
print(f"Shape:\n{main_df.shape}\n")
print(main_df.info())
# Out:
# Shape:
# (3140, 108)
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3140 entries, 0 to 3139
# Columns: 108 entries, fips to Urban_rural_code
# dtypes: float64(61), int64(45), object(2)
# memory usage: 2.6+ MB
# None

# %%
print(main_df.describe(include='all'))
# Out:
#                 fips       TOT_POP           0-9  0-9 y/o % of total pop  \
# count    3140.000000  3.140000e+03  3.140000e+03             3140.000000
# unique           NaN           NaN           NaN                     NaN
# top              NaN           NaN           NaN                     NaN
# freq             NaN           NaN           NaN                     NaN
# mean    30401.640764  1.041894e+05  1.274030e+04               11.871051
# std     15150.559265  3.335834e+05  4.180730e+04                2.124081
# min      1001.000000  8.800000e+01  0.000000e+00                0.000000
# 25%     18180.500000  1.096325e+04  1.280500e+03               10.594639
# 50%     29178.000000  2.580050e+04  3.057000e+03               11.802727
# 75%     45081.500000  6.791300e+04  8.097000e+03               12.951840
# max     56045.000000  1.010552e+07  1.208253e+06               25.460677
#
#               19-Oct  10-19 y/o % of total pop         20-29  \
# ...

# %% [markdown]
# <h3>Datos</h3>
#
# <span style="color: steelblue;">* </span><span style="color: grey;">Dato posiblemente irrelevante para el análisis</span>
# <br>
# <span style="color: green;">* </span><span style="color: grey;">Dato redundante</span>
# <br>
# <span style="color: red;">* </span><span style="color: grey;">Variable objetivo</span>
# <br>
# <br>
#
# | COLUMNA                                       | DESCRIPCIÓN                                                                                          | TIPO |                                        |
# |-----------------------------------------------|------------------------------------------------------------------------------------------------------|------|----------------------------------------|
# | `fips`                                        | Código FIPS del condado. El código FIPS es un identificador único para cada condado en los EE.UU.    | Num  |<span style="color: steelblue;">*</span>|
# | `TOT_POP`                                     | Población total del condado.                                                                         | Num  |                                        |
# | Rangos de edad                                |                                                                                                      |      |                                        |
# | `0-9`                                         | Número de personas de 0 a 9 años en el condado.                                                      | Num  |                                        |
# | `0-9 y/o % of total pop`                      | Porcentaje de la población total que tiene entre 0 y 9 años.                                         | Num  |<span style="color: steelblue;">*</span>|
# | `19-Oct`                                      | Número de personas de 10 a 19 años en el condado.                                                    | Num  |                                        |
# | `10-19 y/o % of total pop`                    | Porcentaje de la población total que tiene entre 10 y 19 años.                                       | Num  |<span style="color: steelblue;">*</span>|
# | `20-29`                                       | Número de personas de 20 a 29 años en el condado.                                                    | Num  |                                        |
# | `20-29 y/o % of total pop`                    | Porcentaje de la población total que tiene entre 20 y 29 años.                                       | Num  |<span style="color: steelblue;">*</span>|
# | `30-39`                                       | Número de personas de 30 a 39 años en el condado.                                                    | Num  |                                        |
# | `30-39 y/o % of total pop`                    | Porcentaje de la población total que tiene entre 30 y 39 años.                                       | Num  |<span style="color: steelblue;">*</span>|
# | `40-49`                                       | Número de personas de 40 a 49 años en el condado.                                                    | Num  |                                        |
# | `40-49 y/o % of total pop`                    | Porcentaje de la población total que tiene entre 40 y 49 años.                                       | Num  |<span style="color: steelblue;">*</span>|
# | `50-59`                                       | Número de personas de 50 a 59 años en el condado.                                                    | Num  |                                        |
# | `50-59 y/o % of total pop`                    | Porcentaje de la población total que tiene entre 50 y 59 años.                                       | Num  |<span style="color: steelblue;">*</span>|
# | `60-69`                                       | Número de personas de 60 a 69 años en el condado.                                                    | Num  |                                        |
# | `60-69 y/o % of total pop`                    | Porcentaje de la población total que tiene entre 60 y 69 años.                                       | Num  |<span style="color: steelblue;">*</span>|
# | `70-79`                                       | Número de personas de 70 a 79 años en el condado.                                                    | Num  |                                        |
# | `70-79 y/o % of total pop`                    | Porcentaje de la población total que tiene entre 70 y 79 años.                                       | Num  |<span style="color: steelblue;">*</span>|
# | `80+`                                         | Número de personas de más de 80 años en el condado.                                                  | Num  |                                        |
# | `80+ y/o % of total pop`                      | Porcentaje de la población total que tiene más de 80 años.                                           | Num  |<span style="color: steelblue;">*</span>|
# | Razas                                         |                                                                                                      |      |                                        |
# | `White-alone pop`                             | Número de personas de raza blanca en el condado.                                                     | Num  |                                        |
# | `% White-alone`                               | Porcentage de personas de raza blanca en el condado.                                                 | Num  |<span style="color: steelblue;">*</span>|
# | `Black-alone pop`                             | Número de personas de raza negra en el condado.                                                      | Num  |                                        |
# | `% Black-alone`                               | Porcentage de personas de raza negra en el condado.                                                  | Num  |<span style="color: steelblue;">*</span>|
# | `Native American/American Indian-alone pop`   | Número de personas de raza nativo americana en el condado.                                           | Num  |                                        |
# | `% NA/AI-alone`                               | Porcentage de personas de raza nativo americana en el condado.                                       | Num  |<span style="color: steelblue;">*</span>|
# | `Asian-alone pop`                             | Número de personas de raza asiática en el condado.                                                   | Num  |                                        |
# | `% Asian-alone`                               | Porcentage de personas de raza asiática en el condado.                                               | Num  |<span style="color: steelblue;">*</span>|
# | `Hawaiian/Pacific Islander-alone pop`         | Número de personas de raza  hawaiana o isleña del Pacífico en el condado.                            | Num  |                                        |
# | `% Hawaiian/PI-alone`                         | Porcentage de personas de raza  hawaiana o isleña del Pacífico en el condado.                        | Num  |<span style="color: steelblue;">*</span>|
# | `Two or more races pop`                       | Número de personas con dos razas o más en el condado.                                                | Num  |                                        |
# | `% Two or more races`                         | Porcentage de personas con dos razas o más en el condado.                                            | Num  |<span style="color: steelblue;">*</span>|
# | Cambios en la población                       |                                                                                                      |      |                                        |
# | `POP_ESTIMATE_2018`                           | Estimación de la población en 2018.                                                                  | Num  |                                        |
# | `N_POP_CHG_2018`                              | Cambio neto de la población en 2018.                                                                 | Num  |                                        |
# | `GQ_ESTIMATES_2018`                           | Estimación de la población en grupos de vivienda - hogares colectivos.                               | Num  |                                        |
# | `R_birth_2018`                                | Tasa de nacimientos en 2018.                                                                         | Num  |                                        |
# | `R_death_2018`                                | Tasa de mortalidad en 2018.                                                                          | Num  |                                        |
# | `R_NATURAL_INC_2018`                          | Cambio natural de la población debido a nacimientos y muertes.                                       | Num  |                                        |
# | Migraciones                                   |                                                                                                      |      |                                        |
# | `R_INTERNATIONAL_MIG_2018`                    | Migración internacional en 2018.                                                                     | Num  |                                        |
# | `R_DOMESTIC_MIG_2018`                         | Migración interna en 2018.                                                                           | Num  |                                        |
# | `R_NET_MIG_2018`                              | Migración neta en 2018                                                                               | Num  |                                        |
# | Estudios                                      |                                                                                                      |      |                                        |
# | `Less than a high school diploma 2014-18`     | Población con estudios inferiores a secundaria (2014-2018)                                           | Num  |                                        |
# | `High school diploma only 2014-18`            | Población con estudios equivalentes a secundaria (2014-2018)                                         | Num  |                                        |
# | `Some college or associate's degree 2014-18`  | Población con algo de educación universitaria o un título de asociado (2014-2018)                    | Num  |                                        |
# | `Bachelor's degree or higher 2014-18`         | Población con un título universitario de licenciatura o superior (2014-2018).                        | Num  |                                        |
# | `% with less than a high school diploma 2014-18`| Porcentage de adultos con estudios inferiores a secundaria (2014-2018)                             | Num  |<span style="color: steelblue;">*</span>|
# | `% with a high school diploma only 2014-18`     | Porcentage de adultos con estudios equivalentes a secundaria (2014-2018)                           | Num  |<span style="color: steelblue;">*</span>|
# | `% completing some college or associate's degree 2014-18`| Porcentage de adultos con algo de educación universitaria (2014-2018)                     | Num  |<span style="color: steelblue;">*</span>|
# | `% with less than a high school diploma 2014-18`| Porcentage de adultos con estudios inferiores a secundaria (2014-2018)                             | Num  |<span style="color: steelblue;">*</span>|
# | `% with a bachelor's degree or higher 2014-18`| Porcentage de adultos con un título universitario de licenciatura o superior (2014-2018)             | Num  |<span style="color: steelblue;">*</span>|
# | Pobreza                                       |                                                                                                      |      |                                        |
# | `POVALL_2018`                                 | Número total de personas en situación de pobreza en 2018.                                            | Num  |                                        |
# | `PCTPOVALL_2018`                              | Porcentaje del total de la población en situación de pobreza en 2018.                                | Num  |<span style="color: steelblue;">*</span>|
# | Población menor de edad                       |                                                                                                      |      |                                        |
# | `PCTPOV017_2018`                              | Porcentaje de la población menor de 17 años en situación de pobreza en 2018.                         | Num  |                                        |
# | `PCTPOV517_2018`                              | Porcentaje de la población entre 5 y 17 años en situación de pobreza en 2018.                        | Num  |<span style="color: steelblue;">*</span>|
# | Ingresos por hogar                            |                                                                                                      |      |                                        |
# | `MEDHHINC_2018`                               | Mediana del ingreso por hogar en 2018.                                                               | Num  |                                        |
# | `CI90LBINC_2018`                              | Límite inferior del intervalo de confianza al 90% para el ingreso por hogar en 2018.                 | Num  |                                        |
# | `CI90UBINC_2018`                              | Límite superior del intervalo de confianza al 90% para el ingreso por hogar en 2018.                 | Num  |                                        |
# |                                               |                                                                                                      |      |                                        |
# | `Civilian_labor_force_2018`                   | Fuerza laboral civil total en 2018 (excluye militares y población institucionalizada).               | Num  |                                        |
# | `Employed_2018`                               | Número total de personas empleadas en 2018.                                                          | Num  |                                        |
# | `Unemployed_2018`                             | Número total de personas desempleadas en 2018.                                                       | Num  |                                        |
# | `Unemployment_rate_2018`                      | Tasa de desempleo como porcentaje de la fuerza laboral civil en 2018.                                | Num  |                                        |
# | Ingresos por hogar                            |                                                                                                      |      |                                        |
# | `Median_Household_Income_2018`                | Ingreso medio por hogar en 2018 (en dólares).                                                        | Num  |                                        |
# | `Med_HH_Income_Percent_of_State_Total_2018`   | Porcentaje del ingreso medio del hogar en relación con el total del estado en 2018.                  | Num  |                                        |
# | Profesionales de la salud activos             |                                                                                                      |      |                                        |
# | `Active Physicians per 100000 Population 2018 (AAMC)`| Número de médicos activos por cada 100,000 habitantes en 2018 (según la AAMC).                | Num  |                                        |
# | `Total Active Patient Care Physicians per 100000 Population 2018 (AAMC)`| Número total de médicos activos dedicados al cuidado de pacientes.         | Num  |                                        |
# | `Active Primary Care Physicians per 100000 Population 2018 (AAMC)`| Número total de médicos activos en atención primaria.                            | Num  |                                        |
# | `Active Patient Care Primary Care Physicians per 100000 Population 2018 (AAMC)`| Número total de médicos activos dedicados al cuidado de pacientes en atención primaria. | Num  |                                        |
# | `Active General Surgeons per 100000 Population 2018 (AAMC)`| Número total de cirujanos generales activos.                                            | Num  |                                        |
# | `Active Patient Care General Surgeons per 100000 Population 2018 (AAMC)`| Número total de cirujanos generales activos dedicados al cuidado de pacientes.| Num  |                                     |
# | Profesionales de la salud y centros           |                                                                                                      |      |                                        |
# | `Total nurse practitioners (2019)`            | Número total de enfermeras practicantes en 2019.                                                     | Num  |                                        |
# | `Total physician assistants (2019)`           | Número total de asistentes médicos en 2019.                                                          | Num  |                                        |
# | `Total Hospitals (2019)`                      | Número total de hospitales en 2019.                                                                  | Num  |                                        |
# | `Internal Medicine Primary Care (2019)`       | Número de médicos de medicina interna en atención primaria en 2019.                                  | Num  |                                        |
# | `Family Medicine/General Practice Primary Care (2019)`| Número de médicos de familia o medicina general en atención primaria en 2019.                | Num  |                                        |
# | `Total Specialist Physicians (2019)`          | Número total de médicos especialistas en 2019.                                                       | Num  |                                        |
# | `ICU Beds_x`                                  | Número de camas de UCI disponibles en el condado.                                                    | Num  |                                        |
# | Población                                     |                                                                                                      |      |                                        |
# | `Total Population`                            | Población total del condado.                                                                         | Num  | <span style="color: green;">*</span>   |
# | `Population Aged 60+`                         | Población de 60 años o más en el condado.                                                            | Num  | <span style="color: green;">*</span>   |
# | `Percent of Population Aged 60+`              | Porcentaje de la población total que tiene 60 años o más.                                            | Num  | <span style="color: green;">*</span>   |
# | `COUNTY_NAME`                                 | Nombre del condado.                                                                                  | Num  |                                        |
# | `STATE_NAME`                                  | Nombre del estado.                                                                                   | Num  |                                        |
# | `STATE_FIPS`                                  | Código FIPS del estado.                                                                              | Num  |<span style="color: steelblue;">*</span>|
# | `CNTY_FIPS`                                   | Código FIPS del condado.                                                                             | Num  |<span style="color: steelblue;">*</span>|
# | `county_pop2018_18 and older`                 | Población del condado de 18 años o más en 2018.                                                      | Num  |                                        |
# | Condiciones de salud                          |                                                                                                      |      |                                        |
# | `anycondition_prevalence`                     | Prevalencia de cualquier condición de salud en la población.                                         | Num  |                                        |
# | `anycondition_Lower 95% CI`                   | Límite inferior del intervalo de confianza al 95% para la prevalencia de cualquier condición de salud.| Num  |<span style="color: steelblue;">*</span>|
# | `anycondition_Upper 95% CI`                   | Límite superior del intervalo de confianza al 95% para la prevalencia de cualquier condición de salud.| Num  |<span style="color: steelblue;">*</span>|
# | `anycondition_number`                         | Número absoluto de personas con alguna condición de salud en la población.                           | Num  |                                        |
# | `Obesity_prevalence`                          | Prevalencia de la obesidad en la población.                                                          | Num  |                                        |
# | `Obesity_Lower 95% CI`                        | Límite inferior del intervalo de confianza al 95% para la prevalencia de la obesidad.                | Num  |<span style="color: steelblue;">*</span>|
# | `Obesity_Upper 95% CI`                        | Límite superior del intervalo de confianza al 95% para la prevalencia de la obesidad.                | Num  |<span style="color: steelblue;">*</span>|
# | `Obesity_number`                              | Número absoluto de personas con obesidad en la población.                                            | Num  |                                        |
# | `Heart disease_prevalence`                    | Prevalencia de enfermedades cardíacas en la población.                                               | Num  |                                        |
# | `Heart disease_Lower 95% CI`                  | Límite inferior del intervalo de confianza al 95% para la prevalencia de enfermedades cardíacas.     | Num  |<span style="color: steelblue;">*</span>|
# | `Heart disease_Upper 95% CI`                  | Límite superior del intervalo de confianza al 95% para la prevalencia de enfermedades cardíacas.     | Num  |<span style="color: steelblue;">*</span>|
# | `Heart disease_number`                        | Número absoluto de personas con enfermedades cardíacas en la población.                              | Num  |                                        |
# | `COPD_prevalence`                             | Prevalencia de la Enfermedad Pulmonar Obstructiva Crónica (COPD) en la población.                    | Num  |                                        |
# | `COPD_Lower 95% CI`                           | Límite inferior del intervalo de confianza al 95% para la prevalencia de la enfermedad pulmonar obstructiva crónica.| Num  |<span style="color: steelblue;">*</span>|
# | `COPD_Upper 95% CI`                           | Límite superior del intervalo de confianza al 95% para la prevalencia de la enfermedad pulmonar obstructiva crónica.| Num  |<span style="color: steelblue;">*</span>|
# | `COPD_number`                                 | Número absoluto de personas con Enfermedad Pulmonar Obstructiva Crónica (COPD) en la población.      | Num  |                                        |
# | `diabetes_prevalence`                         | Prevalencia de la diabetes en la población.                                                          | Num  |                                        |
# | `diabetes_Lower 95% CI`                       | Límite inferior del intervalo de confianza al 95% para la prevalencia de la diabetes.                | Num  |<span style="color: steelblue;">*</span>|
# | `diabetes_Upper 95% CI`                       | Límite superior del intervalo de confianza al 95% para la prevalencia de la diabetes.                | Num  |<span style="color: steelblue;">*</span>|
# | `diabetes_number`                             | Número absoluto de personas con diabetes en la población.                                            | Num  |                                        |
# | `CKD_prevalence`                              | Prevalencia de la Enfermedad Renal Crónica (CKD) en la población.                                    | Num  |                                        |
# | `CKD_Lower 95% CI`                            | Límite inferior del intervalo de confianza al 95% para la prevalencia de la Enfermedad Renal Crónica.| Num  |<span style="color: steelblue;">*</span>|
# | `CKD_Upper 95% CI`                            | Límite superior del intervalo de confianza al 95% para la prevalencia de la Enfermedad Renal Crónica.| Num  |<span style="color: steelblue;">*</span>|
# | `CKD_number`                                  | Número absoluto de personas con Enfermedad Renal Crónica (CKD) en la población.                      | Num  |                                        |
# | `Urban_rural_code`                            | Código que clasifica las áreas como urbanas o rurales.                                               | Num  |                                        |
